# %% [markdown]
# # Сюда делайте признаки
#
# **каждый признак хранится в датафрейме**
#
#
# столбец имеет вид {день}_{имя_признака}
#
# пример ниже

# %%
import pandas as pd

# %%
# Открытие каналов

df_ndvi = pd.read_csv("data/train/NDVI.csv", encoding="windows-1251").drop(columns=["index"])
df_nir = pd.read_csv("data/train/B8A.csv", encoding="windows-1251").drop(columns=["index"])
df_swir = pd.read_csv("data/train/B12.csv", encoding="windows-1251").drop(columns=["index"])

# %%
# Вставка средних значений вместо пустых
days = list(df_ndvi.select_dtypes(include="number"))

for day in days:
    df_ndvi[day] = df_ndvi[day].fillna(df_ndvi[day].mean())
    df_nir[day] = df_nir[day].fillna(df_nir[day].mean())
    df_swir[day] = df_swir[day].fillna(df_swir[day].mean())

# %%
df_ndwi = pd.DataFrame()
df_new = pd.DataFrame()

# %%
for day in days:
    df_ndwi[f"{day}_NDWI"] = (df_nir[day] - df_swir[day]) / (df_nir[day] + df_swir[day])
    df_new[f"{day}_NEW"] = df_ndvi[day] * df_ndwi[f"{day}_NDWI"]

# %%
# пример одного из признаков

df_ndwi.head()
# Out:
#    121_NDWI  128_NDWI  135_NDWI  142_NDWI  149_NDWI  156_NDWI  163_NDWI  \
# 0  0.113090  0.565661  0.154762  0.191711 -0.189464 -0.234547  0.210111
# 1  0.098646  0.422390 -0.018125  0.111130  0.095183 -0.140899  0.078318
# 2  0.148216  0.563218  0.139315  0.125823 -0.177949 -0.195134  0.128298
# 3  0.148270  0.560996  0.157647  0.152444 -0.159228 -0.201506  0.210854
# 4  0.309692  0.539402  0.166240  0.291236 -0.207482 -0.472890  0.115928
#
#    170_NDWI  177_NDWI  184_NDWI  ...  233_NDWI  240_NDWI  247_NDWI  254_NDWI  \
# 0 -0.077288  0.212070 -0.180600  ...  0.434826  0.508137  0.508409  0.142427
# 1  0.123046  0.212455  0.201431  ...  0.479277  0.563585  0.734832  0.543435
# 2 -0.052795  0.193631 -0.160953  ...  0.426582  0.522956  0.410135  0.167625
# 3 -0.048826  0.198323 -0.147525  ...  0.428022  0.516386  0.489820  0.162259
# 4  0.017760  0.149853  0.022646  ...  0.208784  0.552213  0.356886  0.206686
#
#    261_NDWI  268_NDWI  275_NDWI  282_NDWI  289_NDWI  296_NDWI
# 0  0.356951  0.244736  0.325066  0.141581  0.294194  0.021467
# 1  0.323434  0.227638  0.122519 -0.248328  0.352862 -0.119033
# 2  0.300755  0.176114  0.319325  0.101463  0.261075  0.017954
# 3  0.336513  0.252001  0.315730  0.064065  0.274855  0.038358
# 4  0.417060  0.339121  0.330784 -0.231754  0.365094  0.055362
#
# [5 rows x 26 columns]
